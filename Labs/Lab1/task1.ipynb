# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
name_gray = np.array([
    [255, 0, 255, 255, 255, 255, 255, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255],
    [255, 0, 0, 255, 255, 255, 0, 0, 255, 0, 255, 255, 255, 255, 0, 255, 255, 255, 255],
    [255, 0, 255, 0, 255, 0, 255, 0, 255, 0, 0, 0, 0, 255, 0, 0, 0, 0, 255],
    [255, 0, 255, 255, 0, 255, 255, 0, 255, 0, 255, 255, 0, 255, 0, 255, 255, 0, 255],
    [255, 0, 255, 255, 255, 255, 255, 0, 255,  0, 0, 0, 0, 255, 0, 0, 0, 0, 255]
])

plt.imshow(name_gray,cmap='gray')
